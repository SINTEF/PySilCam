# %%
import pysilcam.tests.synthesizer as synth

# %% [markdown]
# # This function will generate a pdf file showing statistics associated with measurements of size distributions according to the setup specified

# %%
synth.generate_report('imagesynth_report.pdf', PIX_SIZE = 28.758169934640524/4,
                    PATH_LENGTH=3, d50 = 300, TotalVolumeConcentration = 100,
                    MinD = 108/4)
# Out:
# /mnt/int5/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /mnt/int5/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# Analysis failed
